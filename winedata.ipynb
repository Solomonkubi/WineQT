# %%
# Pandas - Loading files and working with dataframe
# Numpy - Used to manipulate the dataframe 
# Scipy - Numpy + some advanced features
# Matplotlib - Plottling and visualization
# Seaborn - Plotting and visualization

# %%
# Import the packages 
import pandas as pd 
import numpy as np
import scipy as scp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read and load the file
wine_datatset = pd.read_csv('WineQT.csv', header=0)
# Load only the first 1000 rows
wine_datatset.head(100)

# load only the last 100 rows 
wine_datatset.tail(100)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1043            7.3             0.480         0.32             2.1      0.062
# 1044            6.7             1.040         0.08             2.3      0.067
# 1045            7.3             0.480         0.32             2.1      0.062
# 1046            7.3             0.980         0.05             2.1      0.061
# 1047           10.0             0.690         0.11             1.4      0.084
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
wine_datatset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1141 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1142 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1142 non-null   float64
#  12  Id                    1142 non-null   float64
# dtypes: float64(13)
# memory usage: 116.2 KB

# %%
wine_datatset.duplicated().sum()
# Out:
# np.int64(0)

# %%
# number of rows and number of columns
wine_datatset.shape
# Out:
# (1143, 13)

# %%
# gives basic statistics of dataframe
wine_datatset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1141.000000  1143.000000     1142.000000
# mean        8.311111          0.531078     0.268364        2.532706
# std         1.747595          0.179681     0.196686        1.356382
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
wine_datatset[['fixed acidity', 'quality', 'volatile acidity']]
# how can i get multiple columns
# Out:
#       fixed acidity  quality  volatile acidity
# 0               7.4      5.0             0.700
# 1               7.8      NaN             0.880
# 2               7.8      5.0             0.760
# 3              11.2      6.0             0.280
# 4               7.4      5.0               NaN
# ...             ...      ...               ...
# 1138            6.3      6.0             0.510
# 1139            6.8      6.0             0.620
# 1140            6.2      5.0             0.600
# 1141            5.9      6.0             0.550
# 1142            5.9      5.0             0.645
#
# [1143 rows x 3 columns]

# %%
wine_datatset.dtypes

# %%
# remove or drop a column in a dataframe? 
# Get a count of all  NA in the dataframe
# drop all NAs in the dataframe (either by column or by rows)
# rename a column name
wine_datatset[['quality']]

# %% [markdown]
# 1. the count of null for a column
# 2. count of null for entire dataset

# %%
wine_datatset.isnull()

# %%
null_count = wine_datatset.isnull().sum().sum()
print(null_count)
# Out:
# 5

# %%
null_count = wine_datatset.isnull().sum().sum()
print('Number of null values:', null_count)
# Out:
# Number of null values: 5

# %%
null_count = wine_datatset.isnull().sum()
print('Number of null values:', null_count)
# Out:
# Number of null values: fixed acidity           0
# volatile acidity        2
# citric acid             0
# residual sugar          1
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# Id                      1
# dtype: int64

# %%
null_count = wine_datatset[['volatile acidity', 'alcohol']].isnull().sum()
print('Number of null values:', null_count)
# with doublesq bracket, u can add as many column to analyse
# Out:
# Number of null values: volatile acidity    2
# alcohol             0
# dtype: int64

# %% [markdown]
# 1. upload all to github
# 2. include you as member of the project
# 3. plot pH level and the quality

# %%
wine_datatset.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.countplot(x='quality', data=wine_datatset, palette=['blue'] + ['red'] + ['yellow'])
plt.xlabel('Wine quality')
plt.ylabel('Frequency')
plt.title('Wine quality classes')
plt.show()
# Out:
# C:\Users\paaso\AppData\Local\Temp\ipykernel_68\3879049891.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='quality', data=wine_datatset, palette=['blue'] + ['red'] + ['yellow'])
# C:\Users\paaso\AppData\Local\Temp\ipykernel_68\3879049891.py:1: UserWarning:
# The palette list has fewer values (3) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='quality', data=wine_datatset, palette=['blue'] + ['red'] + ['yellow'])

# %%
#Relation between volatile acidity vs quality
plot = plt.figure(figsize= (6,5))
sns.barplot(x='quality' , y= 'volatile acidity' , data= wine_datatset)
plt.title('volatile acidity and quality');

# %%
plot = plt.figure(figsize= (4,5))
sns.barplot(x='quality' , y= 'pH' , data= wine_datatset)
plt.title('pH and quality');
